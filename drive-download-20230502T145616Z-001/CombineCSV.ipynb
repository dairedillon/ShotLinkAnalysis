# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
import os
os.chdir('/content/drive/MyDrive/GolfData')

# %%
import glob
import pandas as pd

# %%
all_files = glob.glob('*.csv')

# %%
combined_csv = pd.concat([pd.read_csv(f) for f in all_files])

# %%
combined_csv.to_csv('combined_csv.csv', index=False)

# %%
combined_csv
# Out:
#     tour  year  season                      event_name  event_id  \
# 0    pga  2018    2018  Sentry Tournament of Champions        16
# 1    pga  2018    2018  Sentry Tournament of Champions        16
# 2    pga  2018    2018  Sentry Tournament of Champions        16
# 3    pga  2018    2018  Sentry Tournament of Champions        16
# 4    pga  2018    2018  Sentry Tournament of Champions        16
# ..   ...   ...     ...                             ...       ...
# 440  pga  2022    2023                 The RSM Classic       493
# 441  pga  2022    2023                 The RSM Classic       493
# 442  pga  2022    2023                 The RSM Classic       493
# 443  pga  2022    2023                 The RSM Classic       493
# 444  pga  2022    2023                 The RSM Classic       493
#
#          player_name  dg_id fin_text  round_num  \
# 0    Johnson, Dustin  12422        1          1
# 1    Johnson, Dustin  12422        1          2
# ...

# %%
import os

#Rename the CSV file
os.rename('/content/drive/MyDrive/GolfData/combined_csv.csv', '/content/drive/MyDrive/pga_data.csv')

# %%
pga_data = pd.read_csv('/content/drive/MyDrive/pga_data.csv')


print(pga_data.head())
# Out:
#   tour  year  season                      event_name  event_id  \
# 0  pga  2018    2018  Sentry Tournament of Champions        16
# 1  pga  2018    2018  Sentry Tournament of Champions        16
# 2  pga  2018    2018  Sentry Tournament of Champions        16
# 3  pga  2018    2018  Sentry Tournament of Champions        16
# 4  pga  2018    2018  Sentry Tournament of Champions        16
#
#        player_name  dg_id fin_text  round_num                   course_name  \
# 0  Johnson, Dustin  12422        1          1  Plantation Course at Kapalua
# 1  Johnson, Dustin  12422        1          2  Plantation Course at Kapalua
# 2  Johnson, Dustin  12422        1          3  Plantation Course at Kapalua
# 3  Johnson, Dustin  12422        1          4  Plantation Course at Kapalua
# 4        Rahm, Jon  19195        2          1  Plantation Course at Kapalua
#
#    ...  sg_app  sg_ott  sg_t2g  sg_total  driving_dist  driving_acc    gir  \
# ...

# %%
pga_data
# Out:
#       tour  year  season                      event_name  event_id  \
# 0      pga  2018    2018  Sentry Tournament of Champions        16
# 1      pga  2018    2018  Sentry Tournament of Champions        16
# 2      pga  2018    2018  Sentry Tournament of Champions        16
# 3      pga  2018    2018  Sentry Tournament of Champions        16
# 4      pga  2018    2018  Sentry Tournament of Champions        16
# ...    ...   ...     ...                             ...       ...
# 89276  pga  2022    2023                 The RSM Classic       493
# 89277  pga  2022    2023                 The RSM Classic       493
# 89278  pga  2022    2023                 The RSM Classic       493
# 89279  pga  2022    2023                 The RSM Classic       493
# 89280  pga  2022    2023                 The RSM Classic       493
#
#            player_name  dg_id fin_text  round_num  \
# 0      Johnson, Dustin  12422        1          1
# 1      Johnson, Dustin  12422        1          2
# ...

# %%
#Get the shape for an idea of size
num_rows, num_cols = pga_data.shape

#Print them
print("Number of rows: ", num_rows)
print("Number of columns: ", num_cols)
# Out:
# Number of rows:  89281
# Number of columns:  25

# %%
#missing values
missing_values = pga_data.isna().sum()

print(missing_values)
# Out:
# tour               0
# year               0
# season             0
# event_name         0
# event_id           0
# player_name        0
# dg_id              0
# fin_text           0
# round_num          0
# course_name        0
# course_num         0
# course_par         0
# round_score        0
# sg_putt         5114
# sg_arg          5114
# sg_app          5114
# sg_ott          5114
# sg_t2g          5114
# sg_total           0
# driving_dist    5496
# driving_acc     5496
# gir             5936
# scrambling      6379
# prox_rgh        9181
# prox_fw         6338
# dtype: int64
